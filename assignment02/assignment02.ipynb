# %%
 import pandas as pd

# Load CSV Files
df_site = pd.read_csv("D:/College/DSC650/dsc650/data/external/tidynomicon/site.csv")
df_measurement = pd.read_csv("D:/College/DSC650/dsc650/data/external/tidynomicon/measurements.csv")
df_person = pd.read_csv("D:/College/DSC650/dsc650/data/external/tidynomicon/person.csv")
df_visited = pd.read_csv("D:/College/DSC650/dsc650/data/external/tidynomicon/visited.csv")

# %%
 kvdb_path = 'visits.json'
 kvdb = KVDB(kvdb_path)
 key = (619, 'DR-1')
 value = dict(
    visit_id=619,
    site_id='DR-1',
    visit_date='1927-02-08'
 )
 kvdb.set_value(key, value)
 retrieved_value = kvdb.get_value(key)
# Retrieved should be the same as value
